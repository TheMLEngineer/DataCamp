# %%
# !ls
# Out:
#  abc.txt
#  Anaconda3-2019.03-Linux-x86_64.sh
#  axes_demo.ipynb
# 'data visualization on Haberman.ipynb'
# '[FCO] AppliedAICourse - Applied Machine Learning Course'
#  FCO-AppliedAICourse-Applied-Machine-Learning-Course.torrent
# '[FreeCoursesOnline.Me] O'\''REILLY - Python for Data Science Complete Video Course Video Training'
#  FreeCoursesOnline.Me-OREILLY-Python-for-Data-Science-Complete-Video-Course-Video-Training.torrent
# '[FreeCoursesOnline.Me] [UDACITY] Machine Learning Engineer Nanodegree +  Version 1.0.0 [2 In 1] [FCO]'
# 'freecoursesonline me udacity machine learning engineer nanodegree version 1 0 0 2 in 1 fco.torrent'
#  haberman.bck
#  haberman.csv
# 'Intro To Shell For DataScience.ipynb'
#  Iris.csv
# 'ISLR Seventh Printing.pdf'
# 'My Goals and Objectives.pdf'
#  new_csv.csv
#  new_csv.csv.save
#  postgresql-10.9-2-linux-x64.run
#  pycharm-anaconda-2019.1.3
#  pycharm-professional-anaconda-2019.1.3.tar.gz
#  Python-3.7.4
#  Python-3.7.4.tar.xz
#  steps.txt
# ...

# %%
# !head haberman.csv
# Out:
# 30,64,1,1
# 30,62,3,1
# 30,65,0,1
# 31,59,2,1
# 31,65,4,1
# 33,58,10,1
# 33,60,0,1
# 34,59,0,2
# 34,66,9,2
# 34,58,30,1

# %%
# !cut -f 2 -d haberman.csv
# Out:
# cut: the delimiter must be a single character
# Try 'cut --help' for more information.

# %%
# !grep -c 0 haberman.csv
# Out:
# 176

# %%
# !cat haberman.csv
# Out:
# 30,64,1,1
# 30,62,3,1
# 30,65,0,1
# 31,59,2,1
# 31,65,4,1
# 33,58,10,1
# 33,60,0,1
# 34,59,0,2
# 34,66,9,2
# 34,58,30,1
# 34,60,1,1
# 34,61,10,1
# 34,67,7,1
# 34,60,0,1
# 35,64,13,1
# 35,63,0,1
# 36,60,1,1
# 36,69,0,1
# 37,60,0,1
# 37,63,0,1
# 37,58,0,1
# 37,59,6,1
# 37,60,15,1
# 37,63,0,1
# 38,69,21,2
# 38,59,2,1
# 38,60,0,1
# 38,60,0,1
# 38,62,3,1
# 38,64,1,1
# 38,66,0,1
# 38,66,11,1
# 38,60,1,1
# 38,67,5,1
# 39,66,0,2
# 39,63,0,1
# 39,67,0,1
# 39,58,0,1
# 39,59,2,1
# 39,63,4,1
# 40,58,2,1
# 40,58,0,1
# 40,65,0,1
# 41,60,23,2
# 41,64,0,2
# 41,67,0,2
# 41,58,0,1
# 41,59,8,1
# 41,59,0,1
# 41,64,0,1
# 41,69,8,1
# 41,65,0,1
# 41,65,0,1
# 42,69,1,2
# 42,59,0,2
# 42,58,0,1
# 42,60,1,1
# 42,59,2,1
# 42,61,4,1
# 42,62,20,1
# 42,65,0,1
# 42,63,1,1
# 43,58,52,2
# 43,59,2,2
# 43,64,0,2
# 43,64,0,2
# 43,63,14,1
# 43,64,2,1
# 43,64,3,1
# 43,60,0,1
# 43,63,2,1
# 43,65,0,1
# 43,66,4,1
# 44,64,6,2
# 44,58,9,2
# 44,63,19,2
# 44,61,0,1
# 44,63,1,1
# 44,61,0,1
# 44,67,16,1
# 45,65,6,2
# 45,66,0,2
# ...

# %%
# !tail -n 5 haberman.csv > new_csv.csv

# %%
# !tail -n 5 haberman.csv
# Out:
# 75,62,1,1
# 76,67,0,1
# 77,65,3,1
# 78,65,1,2
# 83,58,2,2

# %%
cat new_csv.csv
# Out:
# 75,62,1,1
# 76,67,0,1
# 77,65,3,1
# 78,65,1,2
# 83,58,2,2

# %%
# !grep setosa Iris.csv | wc -l
#Word count
# Out:
# 50

# %%
! cut -d , -f 2 Iris.csv  | sort | uniq -c
# Out:
#       1 4.3
#       3 4.4
#       1 4.5
#       4 4.6
#       2 4.7
#       5 4.8
#       6 4.9
#      10 5.0
#       9 5.1
#       4 5.2
#       1 5.3
#       6 5.4
#       7 5.5
#       6 5.6
#       8 5.7
#       7 5.8
#       3 5.9
#       6 6.0
#       6 6.1
#       4 6.2
#       9 6.3
#       7 6.4
#       5 6.5
#       2 6.6
#       8 6.7
#       3 6.8
#       4 6.9
#       1 7.0
#       1 7.1
#       3 7.2
#       1 7.3
#       1 7.4
#       1 7.6
#       4 7.7
#       1 7.9
#       1 SepalLengthCm

# %%
# !wc -l Iris.csv | sort | head -n 1
# Out:
# 151 Iris.csv

# %%
! echo 'hello'
# Out:
# hello

# %%
! echo $OSTYPE

# %%
! variable=Iris.csv

# %%
# !for f in *;do echo $f;done
# Out:
# Anaconda3-2019.03-Linux-x86_64.sh
# FCO-AppliedAICourse-Applied-Machine-Learning-Course.torrent
# FreeCoursesOnline.Me-OREILLY-Python-for-Data-Science-Complete-Video-Course-Video-Training.torrent
# ISLR Seventh Printing.pdf
# Intro To Shell For DataScience.ipynb
# Iris.csv
# My Goals and Objectives.pdf
# Python-3.7.4
# Python-3.7.4.tar.xz
# Untitled.ipynb
# [FCO] AppliedAICourse - Applied Machine Learning Course
# [FreeCoursesOnline.Me] O'REILLY - Python for Data Science Complete Video Course Video Training
# [FreeCoursesOnline.Me] [UDACITY] Machine Learning Engineer Nanodegree + Version 1.0.0 [2 In 1] [FCO]
# abc.txt
# axes_demo.ipynb
# data visualization on Haberman.ipynb
# freecoursesonline me udacity machine learning engineer nanodegree version 1 0 0 2 in 1 fco.torrent
# haberman.bck
# haberman.csv
# new_csv.csv
# new_csv.csv.save
# postgresql-10.9-2-linux-x64.run
# pycharm-anaconda-2019.1.3
# pycharm-professional-anaconda-2019.1.3.tar.gz
# steps.txt

# %%
# !for f in *.csv;do echo $f;done
# Out:
# Iris.csv
# haberman.csv
# new_csv.csv

# %%
# !for f in *.csv;do grep 3 $f;done
# Out:
# 1,5.1,3.5,1.4,0.2,Iris-setosa
# 2,4.9,3.0,1.4,0.2,Iris-setosa
# 3,4.7,3.2,1.3,0.2,Iris-setosa
# 4,4.6,3.1,1.5,0.2,Iris-setosa
# 5,5.0,3.6,1.4,0.2,Iris-setosa
# 6,5.4,3.9,1.7,0.4,Iris-setosa
# 7,4.6,3.4,1.4,0.3,Iris-setosa
# 8,5.0,3.4,1.5,0.2,Iris-setosa
# 10,4.9,3.1,1.5,0.1,Iris-setosa
# 11,5.4,3.7,1.5,0.2,Iris-setosa
# 12,4.8,3.4,1.6,0.2,Iris-setosa
# 13,4.8,3.0,1.4,0.1,Iris-setosa
# 14,4.3,3.0,1.1,0.1,Iris-setosa
# 17,5.4,3.9,1.3,0.4,Iris-setosa
# 18,5.1,3.5,1.4,0.3,Iris-setosa
# 19,5.7,3.8,1.7,0.3,Iris-setosa
# 20,5.1,3.8,1.5,0.3,Iris-setosa
# 21,5.4,3.4,1.7,0.2,Iris-setosa
# 22,5.1,3.7,1.5,0.4,Iris-setosa
# 23,4.6,3.6,1.0,0.2,Iris-setosa
# 24,5.1,3.3,1.7,0.5,Iris-setosa
# 25,4.8,3.4,1.9,0.2,Iris-setosa
# 26,5.0,3.0,1.6,0.2,Iris-setosa
# 27,5.0,3.4,1.6,0.4,Iris-setosa
# 28,5.2,3.5,1.5,0.2,Iris-setosa
# 29,5.2,3.4,1.4,0.2,Iris-setosa
# 30,4.7,3.2,1.6,0.2,Iris-setosa
# 31,4.8,3.1,1.6,0.2,Iris-setosa
# 32,5.4,3.4,1.5,0.4,Iris-setosa
# 33,5.2,4.1,1.5,0.1,Iris-setosa
# ...

# %%
# !for f in *.csv;do echo $f head -n 2 $f | tail -n 1;done
# Out:
# Iris.csv head -n 2 Iris.csv
# haberman.csv head -n 2 haberman.csv
# new_csv.csv head -n 2 new_csv.csv

# %%
# !ls -ltr
# Out:
# total 1316532
# drwxr-xr-x  18 karthikeyan karthikeyan      4096 Jul  9 00:01  Python-3.7.4
# -rwxrwxr-x   1 karthikeyan karthikeyan 125636407 Jul 21 01:29  postgresql-10.9-2-linux-x64.run
# -rw-rw-r--   1 karthikeyan karthikeyan 685906562 Jul 21 01:46  Anaconda3-2019.03-Linux-x86_64.sh
# -rw-rw-r--   1 karthikeyan karthikeyan 506855848 Jul 21 02:05  pycharm-professional-anaconda-2019.1.3.tar.gz
# drwxr-xr-x  13 karthikeyan karthikeyan      4096 Jul 21 02:10  pycharm-anaconda-2019.1.3
# -rw-rw-r--   1 karthikeyan karthikeyan  17131432 Jul 21 03:02  Python-3.7.4.tar.xz
# -rw-rw-r--   1 karthikeyan karthikeyan     26364 Jul 22 02:20  FreeCoursesOnline.Me-OREILLY-Python-for-Data-Science-Complete-Video-Course-Video-Training.torrent
# -rw-rw-r--   1 karthikeyan karthikeyan    482249 Jul 22 02:20  FCO-AppliedAICourse-Applied-Machine-Learning-Course.torrent
# ...
